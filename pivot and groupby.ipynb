# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('pivotdata.csv')

# %%
df
# Out:
#          date      city  temperature  humidity
# 0  05-01-2017  new york         65.0      56.0
# 1  05-02-2017  new york         66.0      58.0
# 2  05-03-2017  new york         68.0      60.0
# 3  05-01-2017    mumbai         75.0      80.0
# 4  05-02-2017    mumbai         78.0      83.0
# 5  05-03-2017    mumbai         82.0      85.0
# 6  05-01-2017   beijing         80.0      26.0
# 7  05-02-2017   beijing         77.0      30.0
# 8  05-03-2017   beijing         79.0      35.0
# 9         NaN       NaN          NaN       NaN

# %%
df.dropna(axis=0, inplace= True )

# %%
df.pivot(index= "date", columns= "city")
# Out:
#            temperature                 humidity
# city           beijing mumbai new york  beijing mumbai new york
# date
# 05-01-2017        80.0   75.0     65.0     26.0   80.0     56.0
# 05-02-2017        77.0   78.0     66.0     30.0   83.0     58.0
# 05-03-2017        79.0   82.0     68.0     35.0   85.0     60.0

# %%
df
# Out:
#          date      city  temperature  humidity
# 0  05-01-2017  new york         65.0      56.0
# 1  05-02-2017  new york         66.0      58.0
# 2  05-03-2017  new york         68.0      60.0
# 3  05-01-2017    mumbai         75.0      80.0
# 4  05-02-2017    mumbai         78.0      83.0
# 5  05-03-2017    mumbai         82.0      85.0
# 6  05-01-2017   beijing         80.0      26.0
# 7  05-02-2017   beijing         77.0      30.0
# 8  05-03-2017   beijing         79.0      35.0

# %%
df.pivot(index= "date", columns= "city", values= "temperature")
# Out:
# city        beijing  mumbai  new york
# date
# 05-01-2017     80.0    75.0      65.0
# 05-02-2017     77.0    78.0      66.0
# 05-03-2017     79.0    82.0      68.0

# %%
df.pivot(index= "date", columns= "city", values= "humidity")
# Out:
# city        beijing  mumbai  new york
# date
# 05-01-2017     26.0    80.0      56.0
# 05-02-2017     30.0    83.0      58.0
# 05-03-2017     35.0    85.0      60.0

# %%
df.pivot_table(index= "city", columns= "date",)
# Out:
#            humidity                       temperature
# date     05-01-2017 05-02-2017 05-03-2017  05-01-2017 05-02-2017 05-03-2017
# city
# beijing        26.0       30.0       35.0        80.0       77.0       79.0
# mumbai         80.0       83.0       85.0        75.0       78.0       82.0
# new york       56.0       58.0       60.0        65.0       66.0       68.0

# %%
df.pivot_table(index= "city", columns= "date",aggfunc= { "temperature": "sum"}) #mean is default aggregation
# Out:
#          temperature
# date      05-01-2017 05-02-2017 05-03-2017
# city
# beijing         80.0       77.0       79.0
# mumbai          75.0       78.0       82.0
# new york        65.0       66.0       68.0

# %%
df.pivot_table(index= "city", columns= "date",aggfunc= { "temperature": "count", "humidity":"sum"})
# Out:
#            humidity                       temperature
# date     2017-05-01 2017-05-02 2017-05-03  2017-05-01 2017-05-02 2017-05-03
# city
# beijing        26.0       30.0       35.0           1          1          1
# mumbai         80.0       83.0       85.0           1          1          1
# new york       56.0       58.0       60.0           1          1          1

# %%
type(df['date'][0])
# Out:
# str

# %%
df['date']= pd.to_datetime(df['date'])

# %%
type(df['date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.pivot_table(index= pd.Grouper(freq = "M", key= "date"), columns = "city")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.pivot_table(index= pd.Grouper(freq = "M", key= "date"), columns = "city")
#
# NameError: name 'df' is not defined
