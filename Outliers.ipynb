# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("winequality-redD.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00            20.0      0.076
# ...             ...               ...          ...             ...        ...
# 1600            6.2             0.600         0.08             2.0      0.090
# 1601            5.9             0.550         0.10             2.2      0.062
# 1602            6.3             0.510         0.13             2.3      0.076
# 1603            5.9             0.645         0.12             2.0      0.075
# 1604            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                 120.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1600                 32.0                  44.0  0.99490  3.45       0.58
# 1601                 39.0                  51.0  0.99512  3.52       0.76
# 1602                 29.0                  40.0  0.99574  3.42       0.75
# 1603                 32.0                  44.0  0.99547  3.57       0.71
# 1604                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1600     10.5
# 1601     11.2
# 1602     11.0
# 1603     10.2
# 1604     11.0
#
# [1605 rows x 11 columns]

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1605.000000       1605.000000  1605.000000     1605.000000
# mean        8.317570          0.528252     0.271034        3.045265
# std         1.738081          0.178868     0.198039        3.971095
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.660000       66.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1605.000000          1605.000000           1605.000000  1605.000000
# mean      0.087511            16.161246             46.994393     0.996750
# std       0.047038            12.769824             34.962916     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            22.000000             63.000000     0.997840
# max       0.611000           289.800000            440.000000     1.003690
#
#                 pH    sulphates      alcohol
# count  1605.000000  1605.000000  1605.000000
# mean      3.311483     0.657607    10.419595
# std       0.154273     0.169439     1.065195
# min       2.740000     0.330000     8.400000
# 25%       3.210000     0.550000     9.500000
# 50%       3.310000     0.620000    10.200000
# 75%       3.400000     0.730000    11.100000
# max       4.010000     2.000000    14.900000

# %%
sns.displot(df['residual sugar'],height=5,aspect=4)

# %% [markdown]
# #### To see outliers clearly ,Boxplot

# %%
sns.boxplot(df['residual sugar'])
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='residual sugar'>

# %% [markdown]
# ## Z Score Method (to find or remove outlier)

# %%
upper_limit= df['residual sugar'].mean()+3*df['residual sugar'].std()
lower_limit= df['residual sugar'].mean()-3*df['residual sugar'].std()

# %%
print('upper limit:',upper_limit)
print('lower limit:',lower_limit)
# Out:
# upper limit: 14.958549286966539
# lower limit: -8.86801969195096

# %%
df.loc[(df['residual sugar']>upper_limit) | (df['residual sugar']<lower_limit)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            20.0      0.076
# 5               7.4             0.660         0.00            20.0      0.075
# 10              7.4             0.660         0.00            66.8      0.071
# 12              7.3             0.600         0.00            56.0      0.114
# 16              5.6             0.615         0.00            30.0      0.089
# 17              7.8             0.610         0.29            39.0      0.114
# 38              7.8             0.645         0.00            57.0      0.073
# 42              7.8             0.645         0.00            15.0      0.073
# 49              8.1             0.660         0.22            22.0      0.069
# 52              7.7             0.935         0.43            25.0      0.114
# 60              7.6             0.510         0.15            19.0      0.110
# 63              7.5             0.630         0.12            29.0      0.111
# 67              7.7             0.690         0.49            18.0      0.115
# 95              7.0             0.620         0.08            19.0      0.076
# 102             6.8             0.775         0.00            19.0      0.102
# 140             7.9             1.040         0.05            28.0      0.084
# 166             7.6             0.950         0.03            15.0      0.090
# 171             7.8             0.630         0.48            17.0      0.100
# 175             7.5             0.705         0.24            21.0      0.360
# 205             6.9             1.090         0.06            29.0      0.061
# 261             8.0             0.570         0.23            32.0      0.073
# 301            10.8             0.500         0.46            20.0      0.073
# 357             9.1             0.795         0.00            26.0      0.096
# 435            12.8             0.840         0.63            24.0      0.088
# 436            10.5             0.240         0.47            19.0      0.066
# 469             8.1             0.660         0.70            25.0      0.098
# 486            10.6             0.280         0.39            15.5      0.069
# 518            10.7             0.400         0.48            38.0      0.125
# 519            10.5             0.510         0.64            16.0      0.107
# 1440           10.2             0.540         0.37            15.4      0.214
# 1441           10.2             0.540         0.37            15.4      0.214
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4                    11.0                  34.0  0.99780  3.51       0.56
# 5                    13.0                  40.0  0.99780  3.51       0.56
# 10                   19.0                 102.0  0.99780  3.51       0.56
# 12                   11.0                  29.0  0.99640  3.39       0.46
# 16                   16.0                  59.0  0.99430  3.58       0.52
# 17                    9.0                  29.0  0.99740  3.26       1.56
# 38                   40.0                  83.0  0.99930  3.45       0.52
# 42                   40.0                  83.0  0.99930  3.45       0.52
# 49                    9.0                  23.0  0.99680  3.30       1.20
# 52                   22.0                 114.0  0.99700  3.25       0.73
# 60                   33.0                  73.0  0.99550  3.17       0.63
# 63                   50.0                 110.0  0.99830  3.26       0.77
# 67                   20.0                 112.0  0.99680  3.21       0.71
# 95                    8.0                  24.0  0.99780  3.48       0.53
# 102                   8.0                  23.0  0.99650  3.45       0.56
# 140                  13.0                  29.0  0.99590  3.22       0.55
# 166                   7.0                  20.0  0.99590  3.20       0.56
# 171                  14.0                  96.0  0.99610  3.19       0.62
# 175                  15.0                  63.0  0.99640  3.00       1.59
# 205                  12.0                  31.0  0.99480  3.51       0.43
# 261                  17.0                 119.0  0.99675  3.26       0.57
# 301                   5.0                  27.0  1.00010  3.05       0.64
# 357                  11.0                  26.0  0.99940  3.35       0.83
# 435                  13.0                  35.0  0.99970  3.10       0.60
# 436                   6.0                  24.0  0.99780  3.15       0.90
# 469                  25.0                 129.0  0.99720  3.08       0.53
# 486                   6.0                  23.0  1.00260  3.12       0.66
# 518                  15.0                  49.0  0.99800  3.03       0.81
# 519                   6.0                  15.0  0.99730  3.09       0.66
# 1440                 55.0                  95.0  1.00369  3.18       0.77
# 1441                 55.0                  95.0  1.00369  3.18       0.77
#
#       alcohol
# 4         9.4
# 5         9.4
# 10        9.4
# 12       10.0
# 16        9.9
# 17        9.1
# 38        9.4
# 42        9.4
# 49       10.3
# 52        9.2
# 60       10.2
# 63        9.4
# 67        9.3
# 95        9.0
# 102      10.7
# 140       9.9
# 166       9.6
# 171       9.5
# 175       9.5
# 205      11.4
# 261       9.3
# 301       9.5
# 357       9.4
# 435      10.4
# 436      11.0
# 469       9.0
# 486       9.2
# 518       9.7
# 519      11.8
# 1440      9.0
# 1441      9.0

# %%
new_df=df.loc[(df['residual sugar']<upper_limit) & (df['residual sugar']>lower_limit)]
new_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# ...             ...               ...          ...             ...        ...
# 1600            6.2             0.600         0.08             2.0      0.090
# 1601            5.9             0.550         0.10             2.2      0.062
# 1602            6.3             0.510         0.13             2.3      0.076
# 1603            5.9             0.645         0.12             2.0      0.075
# 1604            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                 120.0  0.99800  3.16       0.58
# 6                    15.0                  59.0  0.99640  3.30       0.46
# ...                   ...                   ...      ...   ...        ...
# 1600                 32.0                  44.0  0.99490  3.45       0.58
# 1601                 39.0                  51.0  0.99512  3.52       0.76
# 1602                 29.0                  40.0  0.99574  3.42       0.75
# 1603                 32.0                  44.0  0.99547  3.57       0.71
# 1604                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 6         9.4
# ...       ...
# 1600     10.5
# 1601     11.2
# 1602     11.0
# 1603     10.2
# 1604     11.0
#
# [1574 rows x 11 columns]

# %%
print('lenght of old data:',len(df))
print('lenght of new data:',len(new_df))
print('Outliers:', len(df)-len(new_df))
# Out:
# lenght of old data: 1605
# lenght of new data: 1574
# Outliers: 31

# %%
sns.boxplot(new_df['residual sugar'])
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='residual sugar'>

# %% [markdown]
# #### Capping - changing the outliers values to upper or lower limits

# %%
new_df=df.copy()
new_df.loc[(new_df['residual sugar']>upper_limit)]=upper_limit
new_df.loc[(new_df['residual sugar']<lower_limit)]=lower_limit

# %%
sns.boxplot(new_df['residual sugar'])
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='residual sugar'>

# %% [markdown]
# # IQR method

# %%
q1=df['residual sugar'].quantile(0.25)
q3=df['residual sugar'].quantile(0.75)
iqr=q3-q1

# %%
print(q1,q3,iqr)
# Out:
# 1.9 2.6 0.7000000000000002

# %%
upper_limit=q3+1.5*iqr
lower_limit=q1-1.5*iqr
upper_limit,lower_limit
# Out:
# (3.6500000000000004, 0.8499999999999996)

# %%
sns.boxplot(df['residual sugar'])
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='residual sugar'>

# %%
new_df=df.loc[(df['residual sugar']<upper_limit) & (df['residual sugar']>lower_limit)]
new_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# ...             ...               ...          ...             ...        ...
# 1600            6.2             0.600         0.08             2.0      0.090
# 1601            5.9             0.550         0.10             2.2      0.062
# 1602            6.3             0.510         0.13             2.3      0.076
# 1603            5.9             0.645         0.12             2.0      0.075
# 1604            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                 120.0  0.99800  3.16       0.58
# 6                    15.0                  59.0  0.99640  3.30       0.46
# ...                   ...                   ...      ...   ...        ...
# 1600                 32.0                  44.0  0.99490  3.45       0.58
# 1601                 39.0                  51.0  0.99512  3.52       0.76
# 1602                 29.0                  40.0  0.99574  3.42       0.75
# 1603                 32.0                  44.0  0.99547  3.57       0.71
# 1604                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 6         9.4
# ...       ...
# 1600     10.5
# 1601     11.2
# 1602     11.0
# 1603     10.2
# 1604     11.0
#
# [1401 rows x 11 columns]

# %%
sns.boxplot(new_df['residual sugar'])
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='residual sugar'>

# %%
print('lenght of old data:',len(df))
print('lenght of new data:',len(new_df))
print('Outliers:', len(df)-len(new_df))
# Out:
# lenght of old data: 1605
# lenght of new data: 1401
# Outliers: 204

# %% [markdown]
# # Percentile method

# %%
upper_limit=df['residual sugar'].quantile(0.99)
lower_limit=df['residual sugar'].quantile(0.01)

# %%
print('upper limit:',upper_limit)
print('lower limit:',lower_limit)
# Out:
# upper limit: 20.0
# lower limit: 1.4

# %%
new_df=df.loc[(df['residual sugar']<upper_limit) & (df['residual sugar']>lower_limit)]
new_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# ...             ...               ...          ...             ...        ...
# 1600            6.2             0.600         0.08             2.0      0.090
# 1601            5.9             0.550         0.10             2.2      0.062
# 1602            6.3             0.510         0.13             2.3      0.076
# 1603            5.9             0.645         0.12             2.0      0.075
# 1604            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                 120.0  0.99800  3.16       0.58
# 6                    15.0                  59.0  0.99640  3.30       0.46
# ...                   ...                   ...      ...   ...        ...
# 1600                 32.0                  44.0  0.99490  3.45       0.58
# 1601                 39.0                  51.0  0.99512  3.52       0.76
# 1602                 29.0                  40.0  0.99574  3.42       0.75
# 1603                 32.0                  44.0  0.99547  3.57       0.71
# 1604                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 6         9.4
# ...       ...
# 1600     10.5
# 1601     11.2
# 1602     11.0
# 1603     10.2
# 1604     11.0
#
# [1537 rows x 11 columns]

# %%
print('lenght of old data:',len(df))
print('lenght of new data:',len(new_df))
print('Outliers:', len(df)-len(new_df))
# Out:
# lenght of old data: 1605
# lenght of new data: 1537
# Outliers: 68

# %%
sns.boxplot(new_df['residual sugar'])
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='residual sugar'>
